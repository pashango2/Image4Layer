# %%
import sys
import os
from IPython.display import display
from PIL import Image
sys.path.insert(0, os.path.join(os.getcwd(), ".."))
from image4layer import Image4Layer
os.chdir("../")

# %%
img = Image.open("tests/ducky.png")
effect = Image.open("tests/backdrop.png").convert("RGB")
display(img, effect)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200 at 0x7F59E8F85198>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59E8F851D0>

# %%
Image4Layer.overlay(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D3424630>

# %%
Image4Layer.multiply(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D34245C0>

# %%
Image4Layer.screen(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D34249B0>

# %%
Image4Layer.darken(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D34247B8>

# %%
Image4Layer.lighten(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D3424550>

# %%
Image4Layer.color_dodge(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D3424D68>

# %%
Image4Layer.color_burn(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D3424F60>

# %%
Image4Layer.hard_light(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D3424E10>

# %%
Image4Layer.soft_light(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D3424F28>

# %%
Image4Layer.difference(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D3424B70>

# %%
Image4Layer.exclusion(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59E8F6FE80>

# %%
Image4Layer.vivid(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D343B240>

# %%
Image4Layer.pin_light(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D343B278>

# %%
Image4Layer.linear_dodge(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D343B710>

# %%
Image4Layer.subtract(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D343B4E0>

# %%
Image4Layer.hue(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D343B5F8>

# %%
Image4Layer.saturation(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D343BF98>

# %%
Image4Layer.color(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D343B7B8>

# %%
Image4Layer.luminosity(effect, img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F59D343BB70>
