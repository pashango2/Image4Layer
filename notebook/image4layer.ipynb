# %%
import sys
import os
from IPython.display import display
from PIL import Image
sys.path.insert(0, os.getcwd())
from image4layer import Image4Layer

# %%
img = Image.open("tests/sample.png")
effect = Image.open("tests/effect.png")
display(img, effect)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=250x156 at 0x6701588>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=250x156 at 0x67016A0>

# %%
Image4Layer.over_lay(img, effect)
# Out:
# <PIL.Image.Image image mode=RGB size=250x156 at 0x6701EB8>

# %%
Image4Layer.soft_light(img, effect)
# Out:
# <PIL.Image.Image image mode=RGB size=250x156 at 0x6701E10>

# %%
Image4Layer.hard_light(img, effect)
# Out:
# <PIL.Image.Image image mode=RGB size=250x156 at 0x65A22E8>

# %%
Image4Layer.vivid(img, effect)
# Out:
# <PIL.Image.Image image mode=RGB size=250x156 at 0x6701978>

# %%
Image4Layer.linear_light(img, effect)
# Out:
# <PIL.Image.Image image mode=RGB size=250x156 at 0x6733048>

# %%
Image4Layer.exclusion(img, effect)
# Out:
# <PIL.Image.Image image mode=RGB size=250x156 at 0x65A29E8>

# %%
Image4Layer.pin_light(img, effect)
# Out:
# <PIL.Image.Image image mode=RGB size=250x156 at 0x6733128>
