# %% [markdown]
# #  Image4Layer
#
# It is implemented by 'pillow' in blend mode of CSS3. And more...
#
# # Install
#
# ```
# pip install image4layer
# ```
#
# # Usage

# %%
from PIL import Image
from image4layer import Image4Layer

source = Image.open("tests/ducky.png")
backdrop = Image.open("tests/backdrop.png")

# %%
Image4Layer.__version__
# Out:
# '0.43'

# %% [markdown]
# # Separable blend modes

# %% [markdown]
# ### normal

# %%
Image4Layer.normal(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520140978>

# %% [markdown]
# ### multiply

# %%
Image4Layer.multiply(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520140AC8>

# %% [markdown]
# ### screen

# %%
Image4Layer.screen(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520140A20>

# %% [markdown]
# ### overlay

# %%
Image4Layer.overlay(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC5201404E0>

# %% [markdown]
# ### darken

# %%
Image4Layer.darken(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520140EB8>

# %% [markdown]
# ### lighten

# %%
Image4Layer.lighten(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC5202560F0>

# %% [markdown]
# ### color-dodge

# %%
Image4Layer.color_dodge(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520191208>

# %% [markdown]
# ### color-burn

# %%
Image4Layer.color_burn(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC5201510F0>

# %% [markdown]
# ### hard-light

# %%
Image4Layer.hard_light(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC5201515C0>

# %% [markdown]
# ### soft-light

# %%
Image4Layer.soft_light(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520151470>

# %% [markdown]
# ### difference

# %%
Image4Layer.difference(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC5201514A8>

# %% [markdown]
# ### exclusion

# %%
Image4Layer.exclusion(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520151748>

# %% [markdown]
# # Non-separable blend modes

# %% [markdown]
# ### hue

# %%
Image4Layer.hue(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520140208>

# %% [markdown]
# ### saturation

# %%
Image4Layer.saturation(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520151D30>

# %% [markdown]
# ### color

# %%
Image4Layer.color(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC5201518D0>

# %% [markdown]
# ### luminosity

# %%
Image4Layer.luminosity(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520140320>

# %% [markdown]
# # More blend modes

# %% [markdown]
# ### vivid-light

# %%
Image4Layer.vivid_light(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520151550>

# %% [markdown]
# ### pin-light

# %%
Image4Layer.pin_light(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520151FD0>

# %% [markdown]
# ### linear-dodge

# %%
Image4Layer.linear_dodge(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC5201519E8>

# %% [markdown]
# ### subtract

# %%
Image4Layer.subtract(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7FC520151EB8>
