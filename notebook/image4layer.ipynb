# %% [markdown]
# #  Image4Layer
#
# https://www.w3.org/TR/compositing-1/

# %%
from IPython.display import display
from PIL import Image

import os
import sys
sys.path.insert(0, os.getcwd())
from image4layer import Image4Layer

source = Image.open("tests/ducky.png")
backdrop = Image.open("tests/backdrop.png")
display(source, backdrop)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200 at 0x7F043C44F828>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200 at 0x7F043C0E2550>

# %%
print(Image4Layer.__version__)
# Out:
# 0.3

# %% [markdown]
# # Separable blend modes

# %% [markdown]
# ## Multiply
#
# ```
# B(Cb, Cs) = Cb * Cs
# ```

# %%
Image4Layer.multiply(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C44F240>

# %%
Image4Layer.screen(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C0ECA58>

# %% [markdown]
# ## Overlay
#
# ```
# B(Cb, Cs) = HardLight(Cs, Cb)
# ```

# %%
Image4Layer.overlay(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C0EC8D0>

# %% [markdown]
# ## Darken
# ```
# B(Cb, Cs) = min(Cb, Cs)
# ```

# %%
Image4Layer.darken(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C0ECE10>

# %% [markdown]
# ## Lighten
# ```
# B(Cb, Cs) = max(Cb, Cs)
# ```

# %%
Image4Layer.lighten(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C0ECCF8>

# %% [markdown]
# ## color-dodge
# ```
# if(Cb == 0)
#     B(Cb, Cs) = 0
# else if(Cs == 1)
#     B(Cb, Cs) = 1
# else
#     B(Cb, Cs) = min(1, Cb / (1 - Cs))
# ```

# %%
Image4Layer.color_dodge(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C0ECC88>

# %% [markdown]
# ## color-burn
# ```
# if(Cb == 1)
#     B(Cb, Cs) = 1
# else if(Cs == 0)
#     B(Cb, Cs) = 0
# else
#     B(Cb, Cs) = 1 - min(1, (1 - Cb) / Cs)
# ```

# %%
Image4Layer.color_burn(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C0ECF60>

# %% [markdown]
# ## hard-light
#
# ```
# if(Cs <= 0.5)
#     B(Cb, Cs) = Multiply(Cb, 2 x Cs)
# else
#     B(Cb, Cs) = Screen(Cb, 2 x Cs -1)
# ```

# %%
Image4Layer.hard_light(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C0ECA90>

# %% [markdown]
# ## soft-light
#
# ```
#     if(Cs <= 0.5)
#         B(Cb, Cs) = Cb - (1 - 2 x Cs) x Cb x (1 - Cb)
#     else
#         B(Cb, Cs) = Cb + (2 x Cs - 1) x (D(Cb) - Cb)
# with
#     if(Cb <= 0.25)
#         D(Cb) = ((16 * Cb - 12) x Cb + 4) x Cb
#     else
#         D(Cb) = sqrt(Cb)
# ```

# %%
Image4Layer.soft_light(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C0EC860>

# %%
Image4Layer.difference(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C106160>

# %%
Image4Layer.exclusion(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C1062E8>

# %%
Image4Layer.vivid_light(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C106668>

# %%
Image4Layer.pin_light(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C106438>

# %%
Image4Layer.linear_dodge(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C1063C8>

# %%
Image4Layer.subtract(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C106390>

# %%
Image4Layer.hue(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C106400>

# %%
Image4Layer.hue(backdrop, source).convert("L")
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7F043C44F278>

# %%
Image4Layer.saturation(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C0ECF28>

# %%
Image4Layer.color(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C0ECC18>

# %%
Image4Layer.luminosity(backdrop, source)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F043C106198>
